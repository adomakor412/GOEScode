# %%
import numpy as np #ref
import os
from os import path as op
import string
import re
from subprocess import Popen
import xarray as xr #ref
import metpy #ref
import matplotlib.pyplot as plt #ref
import cartopy.crs as ccrs #ref
import cartopy.feature as cfeature
from pyresample import image, geometry #ref
import seaborn as sns #ref
import netCDF4
sns.set(style="darkgrid")
# %matplotlib inline

#sys.path.append('')
# Out:
# /opt/home/adomakor412/.conda/envs/NOAA/lib/python3.7/site-packages/xarray/core/merge.py:17: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   PANDAS_TYPES = (pd.Series, pd.DataFrame, pd.Panel)

# %%
def create_nc_Numpy(ncFile, pathIn, pathOut):
    myFile = xr.open_dataset(op.join(pathIn,ncFile))
    dat = myFile.metpy.parse_cf('Rad')
    geos = dat.metpy.cartopy_crs

    cartopy_extent_goes = geos.x_limits + geos.y_limits
    pyresample_extent_goes = (cartopy_extent_goes[0],
                                cartopy_extent_goes[2],
                                cartopy_extent_goes[1],
                                cartopy_extent_goes[3])
    goes_params = geos.proj4_params
    rad = dat.data
    
    def normIm(im,gamma=1.0,reverse=False):
        nim = ((im-np.nanmin(im))*(np.nanmax(im)-np.nanmin(im))**(-1))
        if reverse:#want clouds to be white
            nim = (1.0-nim**(gamma))
        return nim
    
    def goes_2_roi(loaded_goes, 
               target_extent,
               target_rows,#actual length or base
               target_cols,#actual width or height
               cartopy_target_proj,
               data_key='Rad',
               radius_of_influence=50000):
        """Function that goes from loaded GOES data to data resampled in a projection for an extent"""
        dat = loaded_goes.metpy.parse_cf('Rad')
        geos_crs = dat.metpy.cartopy_crs
        cartopy_source_extent = geos_crs.x_limits + geos_crs.y_limits
        pyresample_source_extent = (cartopy_source_extent[0],
                                    cartopy_source_extent[2],
                                    cartopy_source_extent[1],
                                    cartopy_source_extent[3])
        rad = dat.data
        source_area = geometry.AreaDefinition('GOES-1X', 'Full Disk','GOES-1X', 
                                              geos_crs.proj4_params,
                                              rad.shape[1], rad.shape[0],
                                              pyresample_source_extent)
        area_target_def = geometry.AreaDefinition('areaTest', 'Target Region', 'areaTest',
                                            cartopy_target_proj.proj4_params,
                                            target_rows, target_cols,
                                            target_extent)
        geos_con_nn = image.ImageContainerNearest(rad, 
                                                source_area, 
                                                radius_of_influence=radius_of_influence)

        # Here we are using pyresample for the remapping
        area_proj_con_nn = geos_con_nn.resample(area_target_def)
        return area_proj_con_nn.image_data
        
    def cartopy_pyresample_toggle_extent(input_extent):
        return np.array(input_extent)[np.array([0,2,1,3])]

    def trasform_cartopy_extent(source_extent,source_proj, target_proj):
        target_extent = target_proj.transform_points(source_proj, 
                                                     np.array(source_extent[:2]),
                                                     np.array(source_extent[2:])).ravel()
        # target_extent in 3D, must be in 2D
        return cartopy_pyresample_toggle_extent(np.array(target_extent)[np.array([0,1,3,4])])
    pc = ccrs.PlateCarree()
    mc = ccrs.Mercator()

    # Convert extent from pc to mc (both cylindrical projections)
    extent_pc = [-109.59326, -102.40674, 8.94659, -8.94656]
    
    target_extent_mc_cartopy = trasform_cartopy_extent(extent_pc, pc, mc)
    target_extent_mc_pyresample = cartopy_pyresample_toggle_extent(target_extent_mc_cartopy)
    
    roi_rads = goes_2_roi(myFile,
               target_extent_mc_pyresample,
               401,1001,
               mc)
    ####
    full_filename = op.join(pathOut,ncFile[:-3])
    np.save(full_filename,roi_rads)
    myFile.close()
    return

# %%
__name__ = '!__main__'
if __name__ == '__main__':#creates npy resampled image data from satellite data
    from pathlib import Path
    newPath = '/sharedData/scratch/'
    path = "G16_G17_url_list/"
    dirs = os.listdir( path )
    for txtFile in dirs:
        txtFileName = txtFile[:-4]
        SS = txtFileName[1:3]
        day = str(int(txtFileName[12:14]) + 90).zfill(3)
        match = 'G' + SS + '_s2019' + day

        subDir = op.join(newPath, 'all_npy3')

        data = Path ( newPath )
        res = [f for f in os.listdir(data) if re.search(match,f)]
        
        with open('log', 'a') as log:
            for nc in res:
                testNC = nc[:-3] + '.npy'
                if Path(op.join(subDir,testNC)).exists() == False:#refactor to check if file already downloaded       
                    try:
                        create_nc_Numpy(nc,newPath,subDir)#names and creates file
                    except OSError as e:
                        print(e)
                        print(nc, file=log)
                        print(e, file=log)
                else:
                    continue

# %%
__name__ = '!__main__'
if __name__ == '__main__':#creates npy resampled image data from CLEAR SKY MASK data
    from pathlib import Path
    fromPath = '/sharedData/scratch/ACMFiles/'
    toPath = '/sharedData/scratch/all_npy3/'
    dirs = os.listdir( fromPath )
    for txtFile in dirs:
        txtFileName = txtFile[:-3]
        downloadName = txtFileName + '.npy'

        with open('log', 'a') as log:    
            if Path(op.join(toPath, downloadName)).exists()==False:
                try:
                    create_ACM_Numpy(txtFile,fromPath,toPath)#names and creates file
                except OSError as e:
                    print(e)
                    print(nc, file=log)
                    print(e, file=log)
            else:
                continue

# %%
def create_ACM_Numpy(ncFile, pathIn, pathOut):
    myFile = xr.open_dataset(op.join(pathIn,ncFile))
    dat = myFile.metpy.parse_cf('BCM')
    geos = dat.metpy.cartopy_crs

    cartopy_extent_goes = geos.x_limits + geos.y_limits
    pyresample_extent_goes = (cartopy_extent_goes[0],
                                cartopy_extent_goes[2],
                                cartopy_extent_goes[1],
                                cartopy_extent_goes[3])
    goes_params = geos.proj4_params
    rad = dat.data
    
    def normIm(im,gamma=1.0,reverse=False):
        nim = ((im-np.nanmin(im))*(np.nanmax(im)-np.nanmin(im))**(-1))
        if reverse:#want clouds to be white
            nim = (1.0-nim**(gamma))
        return nim
    
    def goes_2_roi(loaded_goes, 
               target_extent,
               target_rows,#actual length or base
               target_cols,#actual width or height
               cartopy_target_proj,
               data_key='Rad',
               radius_of_influence=50000):
        """Function that goes from loaded GOES data to data resampled in a projection for an extent"""
        dat = loaded_goes.metpy.parse_cf('BCM')
        geos_crs = dat.metpy.cartopy_crs
        cartopy_source_extent = geos_crs.x_limits + geos_crs.y_limits
        pyresample_source_extent = (cartopy_source_extent[0],
                                    cartopy_source_extent[2],
                                    cartopy_source_extent[1],
                                    cartopy_source_extent[3])
        rad = dat.data
        source_area = geometry.AreaDefinition('GOES-1X', 'Full Disk','GOES-1X', 
                                              geos_crs.proj4_params,
                                              rad.shape[1], rad.shape[0],
                                              pyresample_source_extent)
        area_target_def = geometry.AreaDefinition('areaTest', 'Target Region', 'areaTest',
                                            cartopy_target_proj.proj4_params,
                                            target_rows, target_cols,
                                            target_extent)
        geos_con_nn = image.ImageContainerNearest(rad, 
                                                source_area, 
                                                radius_of_influence=radius_of_influence)

        # Here we are using pyresample for the remapping
        area_proj_con_nn = geos_con_nn.resample(area_target_def)
        return area_proj_con_nn.image_data
        
    def cartopy_pyresample_toggle_extent(input_extent):
        return np.array(input_extent)[np.array([0,2,1,3])]

    def trasform_cartopy_extent(source_extent,source_proj, target_proj):
        target_extent = target_proj.transform_points(source_proj, 
                                                     np.array(source_extent[:2]),
                                                     np.array(source_extent[2:])).ravel()
        # target_extent in 3D, must be in 2D
        return cartopy_pyresample_toggle_extent(np.array(target_extent)[np.array([0,1,3,4])])
    pc = ccrs.PlateCarree()
    mc = ccrs.Mercator()

    # Convert extent from pc to mc (both cylindrical projections)
    extent_pc = [-109.59326, -102.40674, 8.94659, -8.94656]
    
    target_extent_mc_cartopy = trasform_cartopy_extent(extent_pc, pc, mc)
    target_extent_mc_pyresample = cartopy_pyresample_toggle_extent(target_extent_mc_cartopy)
    
    roi_rads = goes_2_roi(myFile,
               target_extent_mc_pyresample,
               401,1001,
               mc)
    ####
    full_filename = op.join(pathOut,ncFile[:-3])
    np.save(full_filename,roi_rads)
    myFile.close()
    return

# %%
__name__ = '__main__'
if __name__ == '__main__':#creates npy resampled image data from satellite data FOR FALL DATA
    from pathlib import Path
    sourcePath = '/sharedData/scratch/fall_data/'
    path = "G16_G17_url_list/"
    dirs = os.listdir( path )
    for txtFile in dirs:
        
        txtFileName = txtFile[:-4]
        SS = txtFileName[1:3]
        day = str(int(txtFileName[12:14]) + 221 - 9).zfill(3)
        match = 'G' + SS + '_s2019' + day

        subDir = '/sharedData/scratch/all_npy3'

        data = Path ( sourcePath )
        res = [f for f in os.listdir(data) if re.search(match,f)]
        with open('log', 'a') as log:
            for nc in res:
                testNC = nc[:-3] + '.npy'
                if Path(op.join(subDir,testNC)).exists() == False:#refactor to check if file already downloaded       
                    try:
                        create_nc_Numpy(nc,sourcePath,subDir)#names and creates file
                    except OSError as e:
                        print(e)
                        print(nc, file=log)
                        print(e, file=log)
                else:
                    continue
# Out:
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device
# [Errno 28] No space left on device: '/sharedData/scratch/all_npy3/OR_ABI-L1b-RadF-M6C08_G16_s20192210040549_e20192210050257_c20192210050328.npy'
# [Errno 28] No space left on device: '/sharedData/scratch/all_npy3/OR_ABI-L1b-RadF-M6C08_G16_s20192210050549_e20192210100257_c20192210100335.npy'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-cdd4f9a1c001> in <module>
#      21                 if Path(op.join(subDir,testNC)).exists() == False:#refactor to check if file already downloaded
#      22                     try:
# ---> 23                         create_nc_Numpy(nc,sourcePath,subDir)#names and creates file
#      24                     except OSError as e:
#      25                         print(e)
#
# <ipython-input-2-f5d361847f40> in create_nc_Numpy(ncFile, pathIn, pathOut)
#      71                target_extent_mc_pyresample,
#      72                401,1001,
# ---> 73                mc)
#      74     ####
#      75     full_filename = op.join(pathOut,ncFile[:-3])
#
# <ipython-input-2-f5d361847f40> in goes_2_roi(loaded_goes, target_extent, target_rows, target_cols, cartopy_target_proj, data_key, radius_of_influence)
#      47
#      48         # Here we are using pyresample for the remapping
# ---> 49         area_proj_con_nn = geos_con_nn.resample(area_target_def)
#      50         return area_proj_con_nn.image_data
#      51
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/image.py in resample(self, target_geo_def)
#     292                                      nprocs=self.nprocs,
#     293                                      reduce_data=self.reduce_data,
# --> 294                                      segments=self.segments)
#     295         return ImageContainerNearest(resampled_image, target_geo_def,
#     296                                      self.radius_of_influence,
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/kd_tree.py in resample_nearest(source_geo_def, data, target_geo_def, radius_of_influence, epsilon, fill_value, reduce_data, nprocs, segments)
#     102                      radius_of_influence, neighbours=1,
#     103                      epsilon=epsilon, fill_value=fill_value,
# --> 104                      reduce_data=reduce_data, nprocs=nprocs, segments=segments)
#     105
#     106
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/kd_tree.py in _resample(source_geo_def, data, target_geo_def, resample_type, radius_of_influence, neighbours, epsilon, weight_funcs, fill_value, reduce_data, nprocs, segments, with_uncert)
#     263                            reduce_data=reduce_data,
#     264                            nprocs=nprocs,
# --> 265                            segments=segments)
#     266
#     267     return get_sample_from_neighbour_info(resample_type,
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/kd_tree.py in get_neighbour_info(source_geo_def, target_geo_def, radius_of_influence, neighbours, epsilon, reduce_data, nprocs, segments)
#     325                                                                          reduce_data,
#     326                                                                          radius_of_influence,
# --> 327                                                                          nprocs=nprocs)
#     328
#     329     # Create kd-tree
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/kd_tree.py in _get_valid_input_index(source_geo_def, target_geo_def, reduce_data, radius_of_influence, nprocs)
#     397     """Find indices of reduced inputput data"""
#     398
# --> 399     source_lons, source_lats = source_geo_def.get_lonlats(nprocs=nprocs)
#     400     source_lons = np.asanyarray(source_lons).ravel()
#     401     source_lats = np.asanyarray(source_lats).ravel()
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/geometry.py in get_lonlats(self, nprocs, data_slice, cache, dtype, chunks)
#    1669
#    1670         # Get corresponding longitude and latitude values
# -> 1671         lons, lats = target_proj(target_x, target_y, inverse=True, nprocs=nprocs)
#    1672         lons = np.asanyarray(lons, dtype=dtype)
#    1673         lats = np.asanyarray(lats, dtype=dtype)
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyresample/_spatial_mp.py in __call__(self, data1, data2, inverse, radians, errcheck, nprocs)
#     155             return data1, data2
#     156         return super(Proj, self).__call__(data1, data2, inverse=inverse,
# --> 157                                           radians=radians, errcheck=errcheck)
#     158
#     159
#
# ~/.conda/envs/NOAA/lib/python3.7/site-packages/pyproj/__init__.py in __call__(self, *args, **kw)
#     399         # call proj4 functions. inx and iny modified in place.
#     400         if inverse:
# --> 401             _proj.Proj._inv(self, inx, iny, radians=radians, errcheck=errcheck)
#     402         else:
#     403             _proj.Proj._fwd(self, inx, iny, radians=radians, errcheck=errcheck)
#
# KeyboardInterrupt:
